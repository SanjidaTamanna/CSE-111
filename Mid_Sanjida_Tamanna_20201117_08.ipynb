# %%
#TASK-1
n = int(input())

dct = {}

for i in range(n):
    STR = input()
    temp = STR.split(' ')

    id = ''
    id = (temp[1])[-2] + (temp[1])[-1] + temp[2] + temp[3]
    value = [temp[4], temp[5]]

    if temp[0] not in dct:
        dct[(temp[0])] = {}

    dct[(temp[0])][id] = value

print(dct)
# Out:
# 5
# Dhanmondi 1209 9A 128 1700sqft 45000
# Mirpur 1216 6B 10 1350sqft 23000
# Dhanmondi 1209 4A 43 1616sqft 40000
# Gulshan 1212 7C 102 2000sqft 60000
# Mirpur 1216 5A 103 1800sqft 33000
# {'Dhanmondi': {'099A128': ['1700sqft', '45000'], '094A43': ['1616sqft', '40000']}, 'Mirpur': {'166B10': ['1350sqft', '23000'], '165A103': ['1800sqft', '33000']}, 'Gulshan': {'127C102': ['2000sqft', '60000']}}

# %%
#TASK-2
class  Dominos:
    def __init__(self,p):
        self.total=0
        self.pizza=p
        self.chk=[0,None]
        self.be=[0,None]
        self.me=[0,None]
        
        print("Domino’s. The Pizza Delivery Experts.")
        
    def showMenu(self):
        print("Total number of pizzas:",self.total)
        print("Chicken Pizza:",self.chk[0])
        for i in range(1,len(self.chk)):
            l=self.chk[i]
            print("Name:",l[0],",Toppings:",l[1:])
        print("Beef Pizza:",self.be[0])
        for i in range(1,len(self.be)):
            l=self.be[i]
            print("Name:",l[0],",Toppings:",l[1:])
        print("Cheese Pizza:",self.me[0])
        for i in range(1,len(self.me)):
            l=self.me[i]
            print("Name:",l[0],",Toppings:",l[1:])

    def addPizza(self,*p):
        for i in p:
            #p.ctg=list[p.ctg]
            if "Chicken" in i.ctg[0]:
                self.chk[0]=self.chk[0]+1
                self.chk.append(i.ctg)
            if "Beef" in i.ctg[0]:
                self.be[0]=self.be[0]+1
                self.be.append(i.ctg)
            else:
                self.me[0]=self.me[0]+1
                self.me.append(i.ctg)
                
        
        
        
class Pizza:
    def __init__(self,*a):
        self.ctg=a
        if "Chicken" not in a[0] or "Beef" not in a[0] :
            print("A pizza without toppings cannot be created.")
    def  setToppings(self,*a):
        self.ctg=self.ctg+a
        
            
        
    
#Write your code here
dom = Dominos("Domino's Pizza")
print("1.=================================")
p1 = Pizza("Spicy Chicken","Spicy Chicken","Onion","Capsicum")
dom.addPizza(p1)
p2 = Pizza("Margherita","Mozzarella Cheese")
print("2.=================================")
p3 = Pizza("Beef Kala Bhuna")
print("3.=================================")
p3.setToppings("Curried Beef","Capsicum","Paprika","Onion")
print("4.=================================")
dom.addPizza(p2,p3)
p4 = Pizza("Chicken Dominator","Barbecue Chicken,Spicy Chicken,Grilled Chicken")
p5 = Pizza("Beefzza","Minced Beef","Beef Pepperoni","Onion","Jalapeno")
dom.addPizza(p4,p5)
print("5.=================================")
dom.showMenu()
print("6.=================================")
